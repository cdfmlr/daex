# %% [markdown]
# # 习题 6.3
#
# ![习题 6.3 描述](https://tva1.sinaimg.cn/large/008i3skNly1grd1uqepz3j31ly07q426.jpg)
# ![习题 6.3 题目](https://tva1.sinaimg.cn/large/008i3skNly1grd1w8x6tpj31gq06ydiz.jpg)

# %%
data <- read.csv("ex_6_3.csv")
attach(data)
data
# Out:
#    Area x1 x2
# 1   1   52 30
# 2   2   50 16
# 3   3   47 23
# 4   4   22 10
# 5   5   16  8
# 6   6   12 13
# 7   7   47 19
# 8   8   12 12
# 9   9   36 10
# 10 10   17 10
# 11 11   38 15
# 12 12   42 22
# 13 13   16  7
# 14 14   22  7
# 15 15   31 11
# 16 16   26  5
# 17 17   34 10
# 18 18   20  6
# 19 19   19 11
# 20 20   42 11
# 21 21   39 13
# 22 22   48 23
# 23 23   14 11
# 24 24   12 14
# 25 25   10 12
# 26 26   46 14
# 27 27   16  9
# 28 28   40 14
# 29 29   18 12
# 30 30   36 15
# ⋮  ⋮    ⋮  ⋮
# 45 45   46 20
# 46 46   13  8
# 47 47   49 22
# 48 48   44 14
# 49 49   40 13
# 50 50   34 10
# 51 51   20  9
# 52 52   19 10
# 53 53   48 14
# 54 54   19 10
# 55 55   49 19
# 56 56   36 12
# 57 57   18  8
# 58 58   26  9
# 59 59   49 17
# 60 60   12 11
# 61 61   12  9
# 62 62   47 14
# 63 63   47 17
# 64 64   34 10
# 65 65   34 12
# 66 66   18  9
# 67 67   48 17
# 68 68   12 12
# 69 69   15  9
# 70 70   50 28
# 71 71   36  6
# 72 72   42 17
# 73 73   18  8
# 74 74   45 18

# %%
plot(x2 ~ x1, data=data)
# Out:
# plot without title

# %% [markdown]
# ## (1) 聚为 3 类

# %%
km3 <- kmeans(data[-1], 3); km3
# Out:
# K-means clustering with 3 clusters of sizes 25, 30, 19
#
# Cluster means:
#      x1        x2
# 1 47.24 18.840000
# 2 17.00  9.366667
# 3 37.00 11.315789
#
# Clustering vector:
#  [1] 1 1 1 2 2 2 1 2 3 2 3 1 2 2 3 2 3 2 2 3 3 1 2 2 2 1 2 3 2 3 3 3 1 2 1 2 1 3
# [39] 2 1 3 3 1 1 1 2 1 1 3 3 2 2 1 2 1 3 2 2 1 2 2 1 1 3 3 2 1 2 2 1 3 1 2 1
#
# Within cluster sum of squares by cluster:
# [1] 599.9200 712.9667 390.1053
#  (between_SS / total_SS =  89.4 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"

# %% [markdown]
# 将结果画在散点图里：

# %%
plot(x2 ~ x1,
     col=km3$cluster, pch = 19,
     data=data)
legend("topleft", legend = paste("Cluster", 1:3), 
       col = 1:3, pch = 19, bty = "n")
# Out:
# plot without title

# %% [markdown]
# 用前两个主成分绘制聚类图:

# %%
library(cluster)
clusplot(data, km3$cluster, color=TRUE, shade=TRUE, labels=2, lines=0)
# Out:
# Plot with title “CLUSPLOT( data )”

# %% [markdown]
# 反应出了各类的聚集性。

# %% [markdown]
# ## (2) 聚为 4 类

# %%
km4 <- kmeans(data[-1], 4); km4
# Out:
# K-means clustering with 4 clusters of sizes 25, 18, 23, 8
#
# Cluster means:
#         x1        x2
# 1 47.24000 18.840000
# 2 37.38889 11.611111
# 3 15.13043  9.956522
# 4 24.00000  7.250000
#
# Clustering vector:
#  [1] 1 1 1 4 3 3 1 3 2 3 2 1 3 4 2 4 2 4 3 2 2 1 3 3 3 1 3 2 3 2 2 2 1 3 1 3 1 2
# [39] 4 1 4 2 1 1 1 3 1 1 2 2 4 3 1 3 1 2 3 4 1 3 3 1 1 2 2 3 1 3 3 1 2 1 3 1
#
# Within cluster sum of squares by cluster:
# [1] 599.9200 308.5556 265.5652 111.5000
#  (between_SS / total_SS =  92.0 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"

# %%
plot(x2 ~ x1,
     col=km4$cluster, pch = 19,
     data=data)
legend("topleft", legend = paste("Cluster", 1:4), 
       col = 1:4, pch = 19, bty = "n")
# Out:
# plot without title

# %%
clusplot(data, km4$cluster, color=TRUE, shade=TRUE, labels=2, lines=0)
# Out:
# Plot with title “CLUSPLOT( data )”
